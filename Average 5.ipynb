# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\a1055035\\OneDrive - PROD - sensata.com Azure AD (sso.sensata.com) (Not O365)\\My Documents\\GitHub\\Electric-five\\01 data'

# %%
Df_Main = pd.read_csv('EnegeryMasterfile.csv')

# %%
Lines = int (input ('How many years ?:'))
# Out:
# How many years ?:5

# %%
#print(' number of lines added  ' + Lines)
#Change = input ('What is the rate of change in % ?:' )
#print (' the moving 5 year avergae is increased by ' + Change + '%'   )

# %%
Df_Main = Df_Main.set_index ('Year')

# %%
Df_Main
# Out:
#       Total_NL  Total_Consumption  NaturalGas_Consumption  \
# Year
# 1990     435.2              29.22                   23.52
# 1991     491.6              32.75                   26.99
# 1992     460.7              30.45                   24.61
# 1993     482.4              31.66                   25.68
# 1994     458.7              29.90                   23.91
# 1995     493.1              31.97                   26.09
# 1996     564.4              36.43                   30.41
# 1997     487.8              31.34                   25.39
# 1998     469.7              30.00                   24.01
# 1999     452.0              28.68                   22.63
# 2000     453.1              28.56                   22.45
# 2001     477.4              29.86                   23.68
# 2002     466.0              28.93                   22.68
# 2003     477.4              29.48                   23.10
# 2004     462.1              28.42                   22.00
# ...

# %%
Table5 = Df_Main.tail(5)

# %%
# for Lines in Table5.index  <- Loop inside a table
# Out:
#   File "<ipython-input-10-89e07cb8c6ae>", line 1
#     for Lines in Table5.index
#                              ^
# SyntaxError: invalid syntax

# %%
#Avg_5 = Table5.mean()

# %%
#Avg_5

# %%
    Avg_501 =Table5.mean() + 0.01*(Table5.mean())

# %%
#Avg_501

# %%
    Table5 = Table5.append(Avg_501 , ignore_index= True)

# %%
    Table5
